# %% [markdown]
# ### Import Libraries

# %%
import pathlib
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras import models

# %% [markdown]
# ### Load Audio File Dataset

# %%
DATASET_PATH = 'dataset'
data_dir = pathlib.Path(DATASET_PATH)

# %% [markdown]
# ### Divide the Dataset into Train and Validation

# %%
train_ds, val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=data_dir,
    batch_size=64,
    validation_split=0.3,
    seed=0,
    output_sequence_length=16000,
    subset='both',
)
# Out:
# Found 6505 files belonging to 4 classes.
# Using 4554 files for training.
# Using 1951 files for validation.

# %%
label_names = np.array(train_ds.class_names)
print(label_names)
num_labels = len(label_names)
# Out:
# ['follow' 'learn' 'tree' 'visual']

# %% [markdown]
# ### Squeezing

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    #removes the last dimension (axis=-1) of the audio tensor
    return audio, labels

# %%
#applies the squeeze function to all elements
train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)
#tf.data.AUTOTUNE helps optimize the preprocessing 
#performance by automatically tuning the number of parallel calls.

# %% [markdown]
# ### Create Testing Data

# %%
test_ds = val_ds.shard(num_shards=2, index=0)
val_ds = val_ds.shard(num_shards=2, index=1)

#.shard() is used to split the dataset into multiple smaller subsets
#- num_shards=2: This means the original dataset (val_ds) is being split into 2 equal parts.
#- index=0: This selects the first shard (i.e., the first half of the dataset) and assigns it to test_ds.
#- index=1: This selects the second shard (i.e., the second half of the dataset) and assigns it back to val_ds.

# %% [markdown]
# ### Generate Spectrogram Data

# %%
def get_spectrogram(waveform):
    #Short-Time Fourier Transform
    spectrogram = tf.signal.stft(
        waveform, frame_length=255, frame_step=128
    )
    #- frame_length=255: Defines the size of each windowed segment.
    #- frame_step=128: Controls the overlap between consecutive windows
    
    #The STFT output contains complex numbers.
    #tf.abs() extracts only the magnitude
    spectrogram = tf.abs(spectrogram)
    #tf.newaxis adds a new dimension, 
    #making the spectrogram suitable for input into a CNN mode
    spectrogram = spectrogram[..., tf.newaxis]
    return spectrogram

# %%
def make_spec_ds(ds):
    return ds.map(
        map_func=lambda audio, label: (get_spectrogram(audio), label),
        num_parallel_calls=tf.data.AUTOTUNE
    )

# %% [markdown]
# ### Converting the Audio Array into A Spectrogram

# %%
train_spectrogram_ds = make_spec_ds(train_ds)
val_spectrogram_ds = make_spec_ds(val_ds)
test_spectrogram_ds = make_spec_ds(test_ds)

# %%
train_spectrogram_ds = train_spectrogram_ds.cache().shuffle(10000).prefetch(tf.data.AUTOTUNE)
val_spectrogram_ds = val_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
test_spectrogram_ds = test_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### Build the Model

# %%
# Ambil satu batch contoh spectrogram dari dataset training
for example_spectrograms, example_spect_labels in train_spectrogram_ds.take(1):
    break

# %%
input_shape = example_spectrograms.shape[1:]
#skips first dimension

# %%
norm_layer = layers.Normalization()
norm_layer.adapt(data=train_spectrogram_ds.map(
    map_func=lambda spec, label: spec  # ambil hanya spectrogram-nya
))

# %%
model = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Resizing(32, 32),
    norm_layer,
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing_1 (Resizing)           │ (None, 32, 32, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization_1 (Normalization) │ (None, 32, 32, 1)      │             3 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 30, 30, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 314,375 (1.20 MB)
#  Trainable params: 314,372 (1.20 MB)
#  Non-trainable params: 3 (16.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# ### Train the Model

# %%
EPOCHS = 10

history = model.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds, 
    epochs=EPOCHS, 
    callbacks=tf.keras.callbacks.EarlyStopping(
        verbose=1,
        patience=2
    ),
)
# Out:
# Epoch 1/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5330 - loss: 1.0527 - val_accuracy: 0.7604 - val_loss: 0.6577
# Epoch 2/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7917 - loss: 0.6003 - val_accuracy: 0.8552 - val_loss: 0.4621
# Epoch 3/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8525 - loss: 0.4324 - val_accuracy: 0.8792 - val_loss: 0.3810
# Epoch 4/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8871 - loss: 0.3391 - val_accuracy: 0.8927 - val_loss: 0.3262
# Epoch 5/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8999 - loss: 0.3001 - val_accuracy: 0.9021 - val_loss: 0.3036
# Epoch 6/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9135 - loss: 0.2468 - val_accuracy: 0.9083 - val_loss: 0.2800
# Epoch 7/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9219 - loss: 0.2225 - val_accuracy: 0.9073 - val_loss: 0.2674
# Epoch 8/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9296 - loss: 0.2026 - val_accuracy: 0.9198 - val_loss: 0.2664
# Epoch 9/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9343 - loss: 0.1880 - val_accuracy: 0.9000 - val_loss: 0.2611
# Epoch 10/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9393 - loss: 0.1766 - val_accuracy: 0.9260 - val_loss: 0.2229

# %% [markdown]
# ### Evaluate the Model

# %%
# Plotting accuracy CNN setiap epoch
metrics = history.history
plt.figure(figsize=(16,6))
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %%
test_results = model.evaluate(test_spectrogram_ds, return_dict=True)
#return_dict agar mudah dapat accuracy
accuracy = test_results['accuracy']
print("Accuracy on test set = {:.2f}%".format(accuracy * 100))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9321 - loss: 0.1982
# Accuracy on test set = 93.34%

# %% [markdown]
# ### Predict

# %%
ctr = 0
#i is batch, j is per item
for i, (spectrogram, label) in enumerate(test_spectrogram_ds):
    pred = model.predict(spectrogram)
    pred_label_idx = tf.argmax(pred, axis=1).numpy()  # Convert to numpy array
    orig_label = label_names[label.numpy()]
    pred_label = [label_names[idx] for idx in pred_label_idx]  # Use list comprehension
    for j, label in enumerate(orig_label):
        ctr += 1
        print("Data %d: Original Label -> %s, Prediction -> %s" % (ctr, label, pred_label[j]))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Data 1: Original Label -> tree, Prediction -> tree
# Data 2: Original Label -> learn, Prediction -> learn
# Data 3: Original Label -> tree, Prediction -> tree
# Data 4: Original Label -> tree, Prediction -> tree
# Data 5: Original Label -> tree, Prediction -> tree
# Data 6: Original Label -> visual, Prediction -> visual
# Data 7: Original Label -> tree, Prediction -> tree
# Data 8: Original Label -> visual, Prediction -> visual
# Data 9: Original Label -> learn, Prediction -> learn
# Data 10: Original Label -> visual, Prediction -> visual
# Data 11: Original Label -> visual, Prediction -> visual
# Data 12: Original Label -> follow, Prediction -> follow
# Data 13: Original Label -> learn, Prediction -> learn
# Data 14: Original Label -> tree, Prediction -> tree
# Data 15: Original Label -> tree, Prediction -> tree
# Data 16: Original Label -> visual, Prediction -> visual
# Data 17: Original Label -> tree, Prediction -> tree
# Data 18: Original Label -> tree, Prediction -> tree
# Data 19: Original Label -> tree, Prediction -> tree
# Data 20: Original Label -> follow, Prediction -> follow
# Data 21: Original Label -> tree, Prediction -> tree
# Data 22: Original Label -> visual, Prediction -> visual
# Data 23: Original Label -> tree, Prediction -> tree
# Data 24: Original Label -> learn, Prediction -> tree
# Data 25: Original Label -> learn, Prediction -> learn
# Data 26: Original Label -> follow, Prediction -> follow
# Data 27: Original Label -> visual, Prediction -> visual
# Data 28: Original Label -> tree, Prediction -> tree
# Data 29: Original Label -> learn, Prediction -> learn
# Data 30: Original Label -> visual, Prediction -> follow
# Data 31: Original Label -> tree, Prediction -> tree
# Data 32: Original Label -> learn, Prediction -> learn
# Data 33: Original Label -> visual, Prediction -> visual
# Data 34: Original Label -> learn, Prediction -> learn
# Data 35: Original Label -> learn, Prediction -> tree
# Data 36: Original Label -> learn, Prediction -> learn
# Data 37: Original Label -> tree, Prediction -> tree
# Data 38: Original Label -> follow, Prediction -> follow
# Data 39: Original Label -> follow, Prediction -> follow
# Data 40: Original Label -> follow, Prediction -> follow
# Data 41: Original Label -> learn, Prediction -> learn
# Data 42: Original Label -> learn, Prediction -> learn
# Data 43: Original Label -> tree, Prediction -> tree
# Data 44: Original Label -> learn, Prediction -> learn
# Data 45: Original Label -> learn, Prediction -> learn
# Data 46: Original Label -> learn, Prediction -> learn
# Data 47: Original Label -> learn, Prediction -> learn
# Data 48: Original Label -> tree, Prediction -> tree
# Data 49: Original Label -> follow, Prediction -> follow
# Data 50: Original Label -> learn, Prediction -> learn
# Data 51: Original Label -> learn, Prediction -> learn
# Data 52: Original Label -> follow, Prediction -> follow
# Data 53: Original Label -> visual, Prediction -> visual
# Data 54: Original Label -> tree, Prediction -> tree
# Data 55: Original Label -> follow, Prediction -> follow
# Data 56: Original Label -> tree, Prediction -> tree
# Data 57: Original Label -> follow, Prediction -> follow
# Data 58: Original Label -> follow, Prediction -> follow
# Data 59: Original Label -> learn, Prediction -> learn
# Data 60: Original Label -> follow, Prediction -> follow
# Data 61: Original Label -> visual, Prediction -> visual
# Data 62: Original Label -> learn, Prediction -> learn
# Data 63: Original Label -> visual, Prediction -> visual
# Data 64: Original Label -> visual, Prediction -> visual
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Data 65: Original Label -> tree, Prediction -> tree
# Data 66: Original Label -> visual, Prediction -> visual
# Data 67: Original Label -> follow, Prediction -> follow
# Data 68: Original Label -> tree, Prediction -> tree
# Data 69: Original Label -> tree, Prediction -> tree
# Data 70: Original Label -> follow, Prediction -> follow
# Data 71: Original Label -> learn, Prediction -> learn
# Data 72: Original Label -> tree, Prediction -> tree
# Data 73: Original Label -> tree, Prediction -> visual
# Data 74: Original Label -> visual, Prediction -> visual
# Data 75: Original Label -> tree, Prediction -> tree
# Data 76: Original Label -> follow, Prediction -> follow
# Data 77: Original Label -> tree, Prediction -> tree
# Data 78: Original Label -> visual, Prediction -> visual
# Data 79: Original Label -> visual, Prediction -> visual
# Data 80: Original Label -> tree, Prediction -> visual
# Data 81: Original Label -> learn, Prediction -> learn
# Data 82: Original Label -> learn, Prediction -> learn
# Data 83: Original Label -> follow, Prediction -> follow
# Data 84: Original Label -> follow, Prediction -> follow
# Data 85: Original Label -> visual, Prediction -> visual
# Data 86: Original Label -> visual, Prediction -> visual
# Data 87: Original Label -> learn, Prediction -> learn
# Data 88: Original Label -> follow, Prediction -> follow
# Data 89: Original Label -> tree, Prediction -> follow
# Data 90: Original Label -> tree, Prediction -> tree
# Data 91: Original Label -> visual, Prediction -> learn
# Data 92: Original Label -> visual, Prediction -> visual
# Data 93: Original Label -> follow, Prediction -> follow
# Data 94: Original Label -> tree, Prediction -> tree
# Data 95: Original Label -> learn, Prediction -> learn
# Data 96: Original Label -> learn, Prediction -> learn
# Data 97: Original Label -> tree, Prediction -> learn
# Data 98: Original Label -> tree, Prediction -> tree
# Data 99: Original Label -> tree, Prediction -> tree
# Data 100: Original Label -> visual, Prediction -> visual
# Data 101: Original Label -> tree, Prediction -> tree
# Data 102: Original Label -> visual, Prediction -> visual
# Data 103: Original Label -> learn, Prediction -> learn
# Data 104: Original Label -> tree, Prediction -> tree
# Data 105: Original Label -> tree, Prediction -> tree
# Data 106: Original Label -> tree, Prediction -> tree
# Data 107: Original Label -> visual, Prediction -> visual
# Data 108: Original Label -> follow, Prediction -> learn
# Data 109: Original Label -> visual, Prediction -> visual
# Data 110: Original Label -> tree, Prediction -> tree
# Data 111: Original Label -> visual, Prediction -> visual
# Data 112: Original Label -> visual, Prediction -> visual
# Data 113: Original Label -> tree, Prediction -> tree
# Data 114: Original Label -> follow, Prediction -> follow
# Data 115: Original Label -> learn, Prediction -> learn
# Data 116: Original Label -> visual, Prediction -> visual
# Data 117: Original Label -> visual, Prediction -> visual
# Data 118: Original Label -> learn, Prediction -> learn
# Data 119: Original Label -> visual, Prediction -> visual
# Data 120: Original Label -> learn, Prediction -> learn
# Data 121: Original Label -> follow, Prediction -> follow
# Data 122: Original Label -> follow, Prediction -> follow
# Data 123: Original Label -> visual, Prediction -> visual
# Data 124: Original Label -> learn, Prediction -> learn
# Data 125: Original Label -> visual, Prediction -> learn
# Data 126: Original Label -> follow, Prediction -> follow
# Data 127: Original Label -> follow, Prediction -> follow
# Data 128: Original Label -> visual, Prediction -> visual
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Data 129: Original Label -> visual, Prediction -> visual
# Data 130: Original Label -> learn, Prediction -> learn
# Data 131: Original Label -> visual, Prediction -> visual
# Data 132: Original Label -> tree, Prediction -> tree
# Data 133: Original Label -> follow, Prediction -> follow
# Data 134: Original Label -> tree, Prediction -> tree
# Data 135: Original Label -> tree, Prediction -> tree
# Data 136: Original Label -> learn, Prediction -> tree
# Data 137: Original Label -> visual, Prediction -> visual
# Data 138: Original Label -> tree, Prediction -> tree
# Data 139: Original Label -> visual, Prediction -> visual
# Data 140: Original Label -> visual, Prediction -> visual
# Data 141: Original Label -> learn, Prediction -> learn
# Data 142: Original Label -> follow, Prediction -> follow
# Data 143: Original Label -> follow, Prediction -> follow
# Data 144: Original Label -> visual, Prediction -> visual
# Data 145: Original Label -> tree, Prediction -> follow
# Data 146: Original Label -> learn, Prediction -> learn
# Data 147: Original Label -> learn, Prediction -> learn
# Data 148: Original Label -> tree, Prediction -> tree
# Data 149: Original Label -> tree, Prediction -> tree
# Data 150: Original Label -> tree, Prediction -> tree
# Data 151: Original Label -> tree, Prediction -> tree
# Data 152: Original Label -> tree, Prediction -> tree
# Data 153: Original Label -> tree, Prediction -> tree
# Data 154: Original Label -> tree, Prediction -> tree
# Data 155: Original Label -> visual, Prediction -> visual
# Data 156: Original Label -> learn, Prediction -> follow
# Data 157: Original Label -> tree, Prediction -> tree
# Data 158: Original Label -> learn, Prediction -> learn
# Data 159: Original Label -> visual, Prediction -> visual
# Data 160: Original Label -> follow, Prediction -> follow
# Data 161: Original Label -> learn, Prediction -> learn
# Data 162: Original Label -> visual, Prediction -> visual
# Data 163: Original Label -> learn, Prediction -> learn
# Data 164: Original Label -> follow, Prediction -> follow
# Data 165: Original Label -> follow, Prediction -> follow
# Data 166: Original Label -> follow, Prediction -> follow
# Data 167: Original Label -> visual, Prediction -> visual
# Data 168: Original Label -> learn, Prediction -> learn
# Data 169: Original Label -> follow, Prediction -> follow
# Data 170: Original Label -> follow, Prediction -> follow
# Data 171: Original Label -> learn, Prediction -> learn
# Data 172: Original Label -> tree, Prediction -> tree
# Data 173: Original Label -> visual, Prediction -> follow
# Data 174: Original Label -> follow, Prediction -> follow
# Data 175: Original Label -> learn, Prediction -> learn
# Data 176: Original Label -> follow, Prediction -> follow
# Data 177: Original Label -> visual, Prediction -> visual
# Data 178: Original Label -> tree, Prediction -> tree
# Data 179: Original Label -> visual, Prediction -> visual
# Data 180: Original Label -> visual, Prediction -> visual
# Data 181: Original Label -> follow, Prediction -> follow
# Data 182: Original Label -> tree, Prediction -> tree
# Data 183: Original Label -> learn, Prediction -> learn
# Data 184: Original Label -> tree, Prediction -> tree
# Data 185: Original Label -> learn, Prediction -> learn
# Data 186: Original Label -> visual, Prediction -> visual
# Data 187: Original Label -> visual, Prediction -> visual
# Data 188: Original Label -> follow, Prediction -> follow
# Data 189: Original Label -> follow, Prediction -> follow
# Data 190: Original Label -> tree, Prediction -> tree
# Data 191: Original Label -> visual, Prediction -> visual
# Data 192: Original Label -> learn, Prediction -> learn
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Data 193: Original Label -> tree, Prediction -> tree
# Data 194: Original Label -> follow, Prediction -> follow
# Data 195: Original Label -> follow, Prediction -> follow
# Data 196: Original Label -> tree, Prediction -> tree
# Data 197: Original Label -> learn, Prediction -> learn
# Data 198: Original Label -> tree, Prediction -> tree
# Data 199: Original Label -> visual, Prediction -> visual
# Data 200: Original Label -> tree, Prediction -> tree
# Data 201: Original Label -> learn, Prediction -> learn
# Data 202: Original Label -> follow, Prediction -> follow
# Data 203: Original Label -> follow, Prediction -> follow
# Data 204: Original Label -> tree, Prediction -> tree
# Data 205: Original Label -> follow, Prediction -> follow
# Data 206: Original Label -> visual, Prediction -> visual
# Data 207: Original Label -> learn, Prediction -> learn
# Data 208: Original Label -> learn, Prediction -> learn
# Data 209: Original Label -> visual, Prediction -> visual
# Data 210: Original Label -> follow, Prediction -> follow
# Data 211: Original Label -> learn, Prediction -> learn
# Data 212: Original Label -> learn, Prediction -> learn
# Data 213: Original Label -> follow, Prediction -> follow
# Data 214: Original Label -> learn, Prediction -> learn
# Data 215: Original Label -> visual, Prediction -> visual
# Data 216: Original Label -> follow, Prediction -> follow
# Data 217: Original Label -> visual, Prediction -> visual
# Data 218: Original Label -> learn, Prediction -> learn
# Data 219: Original Label -> follow, Prediction -> follow
# Data 220: Original Label -> follow, Prediction -> follow
# Data 221: Original Label -> visual, Prediction -> visual
# Data 222: Original Label -> tree, Prediction -> tree
# Data 223: Original Label -> visual, Prediction -> visual
# Data 224: Original Label -> follow, Prediction -> follow
# Data 225: Original Label -> visual, Prediction -> visual
# Data 226: Original Label -> learn, Prediction -> learn
# Data 227: Original Label -> follow, Prediction -> follow
# Data 228: Original Label -> tree, Prediction -> tree
# Data 229: Original Label -> tree, Prediction -> tree
# Data 230: Original Label -> visual, Prediction -> visual
# Data 231: Original Label -> tree, Prediction -> tree
# Data 232: Original Label -> tree, Prediction -> tree
# Data 233: Original Label -> learn, Prediction -> learn
# Data 234: Original Label -> visual, Prediction -> visual
# Data 235: Original Label -> follow, Prediction -> follow
# Data 236: Original Label -> learn, Prediction -> learn
# Data 237: Original Label -> learn, Prediction -> learn
# Data 238: Original Label -> visual, Prediction -> visual
# Data 239: Original Label -> learn, Prediction -> learn
# Data 240: Original Label -> visual, Prediction -> visual
# Data 241: Original Label -> follow, Prediction -> follow
# Data 242: Original Label -> tree, Prediction -> tree
# Data 243: Original Label -> learn, Prediction -> learn
# Data 244: Original Label -> learn, Prediction -> learn
# Data 245: Original Label -> follow, Prediction -> follow
# Data 246: Original Label -> tree, Prediction -> tree
# Data 247: Original Label -> visual, Prediction -> visual
# Data 248: Original Label -> tree, Prediction -> tree
# Data 249: Original Label -> learn, Prediction -> learn
# Data 250: Original Label -> tree, Prediction -> tree
# Data 251: Original Label -> follow, Prediction -> follow
# Data 252: Original Label -> follow, Prediction -> learn
# Data 253: Original Label -> tree, Prediction -> tree
# Data 254: Original Label -> tree, Prediction -> tree
# Data 255: Original Label -> visual, Prediction -> learn
# Data 256: Original Label -> tree, Prediction -> learn
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Data 257: Original Label -> learn, Prediction -> learn
# Data 258: Original Label -> tree, Prediction -> tree
# Data 259: Original Label -> visual, Prediction -> visual
# Data 260: Original Label -> visual, Prediction -> visual
# Data 261: Original Label -> learn, Prediction -> learn
# Data 262: Original Label -> tree, Prediction -> tree
# Data 263: Original Label -> learn, Prediction -> learn
# Data 264: Original Label -> learn, Prediction -> learn
# Data 265: Original Label -> follow, Prediction -> follow
# Data 266: Original Label -> learn, Prediction -> learn
# Data 267: Original Label -> visual, Prediction -> visual
# Data 268: Original Label -> visual, Prediction -> follow
# Data 269: Original Label -> follow, Prediction -> follow
# Data 270: Original Label -> tree, Prediction -> tree
# Data 271: Original Label -> learn, Prediction -> tree
# Data 272: Original Label -> follow, Prediction -> follow
# Data 273: Original Label -> visual, Prediction -> visual
# Data 274: Original Label -> learn, Prediction -> learn
# Data 275: Original Label -> tree, Prediction -> learn
# Data 276: Original Label -> learn, Prediction -> learn
# Data 277: Original Label -> tree, Prediction -> tree
# Data 278: Original Label -> tree, Prediction -> tree
# Data 279: Original Label -> tree, Prediction -> tree
# Data 280: Original Label -> tree, Prediction -> tree
# Data 281: Original Label -> tree, Prediction -> learn
# Data 282: Original Label -> tree, Prediction -> tree
# Data 283: Original Label -> learn, Prediction -> learn
# Data 284: Original Label -> tree, Prediction -> tree
# Data 285: Original Label -> follow, Prediction -> follow
# Data 286: Original Label -> tree, Prediction -> tree
# Data 287: Original Label -> follow, Prediction -> follow
# Data 288: Original Label -> follow, Prediction -> follow
# Data 289: Original Label -> visual, Prediction -> visual
# Data 290: Original Label -> tree, Prediction -> tree
# Data 291: Original Label -> visual, Prediction -> visual
# Data 292: Original Label -> follow, Prediction -> follow
# Data 293: Original Label -> learn, Prediction -> learn
# Data 294: Original Label -> follow, Prediction -> follow
# Data 295: Original Label -> tree, Prediction -> tree
# Data 296: Original Label -> learn, Prediction -> learn
# Data 297: Original Label -> learn, Prediction -> tree
# Data 298: Original Label -> visual, Prediction -> visual
# Data 299: Original Label -> learn, Prediction -> learn
# Data 300: Original Label -> learn, Prediction -> learn
# Data 301: Original Label -> tree, Prediction -> tree
# Data 302: Original Label -> visual, Prediction -> visual
# Data 303: Original Label -> visual, Prediction -> visual
# Data 304: Original Label -> follow, Prediction -> follow
# Data 305: Original Label -> follow, Prediction -> follow
# Data 306: Original Label -> tree, Prediction -> tree
# Data 307: Original Label -> visual, Prediction -> visual
# Data 308: Original Label -> visual, Prediction -> visual
# Data 309: Original Label -> visual, Prediction -> visual
# Data 310: Original Label -> visual, Prediction -> visual
# Data 311: Original Label -> learn, Prediction -> learn
# Data 312: Original Label -> visual, Prediction -> visual
# Data 313: Original Label -> tree, Prediction -> tree
# Data 314: Original Label -> tree, Prediction -> tree
# Data 315: Original Label -> learn, Prediction -> learn
# Data 316: Original Label -> tree, Prediction -> tree
# Data 317: Original Label -> follow, Prediction -> follow
# Data 318: Original Label -> tree, Prediction -> tree
# Data 319: Original Label -> tree, Prediction -> tree
# Data 320: Original Label -> learn, Prediction -> learn
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Data 321: Original Label -> tree, Prediction -> tree
# Data 322: Original Label -> visual, Prediction -> visual
# Data 323: Original Label -> visual, Prediction -> visual
# Data 324: Original Label -> visual, Prediction -> visual
# Data 325: Original Label -> visual, Prediction -> visual
# Data 326: Original Label -> visual, Prediction -> visual
# Data 327: Original Label -> follow, Prediction -> follow
# Data 328: Original Label -> visual, Prediction -> visual
# Data 329: Original Label -> follow, Prediction -> follow
# Data 330: Original Label -> learn, Prediction -> learn
# Data 331: Original Label -> learn, Prediction -> learn
# Data 332: Original Label -> follow, Prediction -> follow
# Data 333: Original Label -> tree, Prediction -> visual
# Data 334: Original Label -> learn, Prediction -> visual
# Data 335: Original Label -> tree, Prediction -> tree
# Data 336: Original Label -> follow, Prediction -> follow
# Data 337: Original Label -> tree, Prediction -> tree
# Data 338: Original Label -> learn, Prediction -> learn
# Data 339: Original Label -> learn, Prediction -> learn
# Data 340: Original Label -> tree, Prediction -> tree
# Data 341: Original Label -> learn, Prediction -> learn
# Data 342: Original Label -> tree, Prediction -> tree
# Data 343: Original Label -> tree, Prediction -> tree
# Data 344: Original Label -> tree, Prediction -> tree
# Data 345: Original Label -> tree, Prediction -> tree
# Data 346: Original Label -> learn, Prediction -> learn
# Data 347: Original Label -> learn, Prediction -> learn
# Data 348: Original Label -> visual, Prediction -> visual
# Data 349: Original Label -> tree, Prediction -> tree
# Data 350: Original Label -> learn, Prediction -> learn
# Data 351: Original Label -> tree, Prediction -> tree
# Data 352: Original Label -> follow, Prediction -> follow
# Data 353: Original Label -> tree, Prediction -> tree
# Data 354: Original Label -> tree, Prediction -> tree
# Data 355: Original Label -> visual, Prediction -> visual
# Data 356: Original Label -> follow, Prediction -> follow
# Data 357: Original Label -> tree, Prediction -> tree
# Data 358: Original Label -> follow, Prediction -> follow
# Data 359: Original Label -> visual, Prediction -> visual
# Data 360: Original Label -> learn, Prediction -> learn
# Data 361: Original Label -> learn, Prediction -> learn
# Data 362: Original Label -> follow, Prediction -> follow
# Data 363: Original Label -> tree, Prediction -> tree
# Data 364: Original Label -> tree, Prediction -> tree
# Data 365: Original Label -> learn, Prediction -> learn
# Data 366: Original Label -> follow, Prediction -> follow
# Data 367: Original Label -> tree, Prediction -> tree
# Data 368: Original Label -> follow, Prediction -> follow
# Data 369: Original Label -> tree, Prediction -> tree
# Data 370: Original Label -> follow, Prediction -> follow
# Data 371: Original Label -> learn, Prediction -> learn
# Data 372: Original Label -> follow, Prediction -> follow
# Data 373: Original Label -> tree, Prediction -> tree
# Data 374: Original Label -> tree, Prediction -> tree
# Data 375: Original Label -> learn, Prediction -> learn
# Data 376: Original Label -> visual, Prediction -> visual
# Data 377: Original Label -> learn, Prediction -> learn
# Data 378: Original Label -> tree, Prediction -> tree
# Data 379: Original Label -> tree, Prediction -> tree
# Data 380: Original Label -> follow, Prediction -> follow
# Data 381: Original Label -> learn, Prediction -> learn
# Data 382: Original Label -> tree, Prediction -> tree
# Data 383: Original Label -> tree, Prediction -> tree
# Data 384: Original Label -> tree, Prediction -> tree
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Data 385: Original Label -> learn, Prediction -> learn
# Data 386: Original Label -> tree, Prediction -> visual
# Data 387: Original Label -> learn, Prediction -> learn
# Data 388: Original Label -> learn, Prediction -> learn
# Data 389: Original Label -> visual, Prediction -> visual
# Data 390: Original Label -> follow, Prediction -> follow
# Data 391: Original Label -> learn, Prediction -> learn
# Data 392: Original Label -> learn, Prediction -> learn
# Data 393: Original Label -> learn, Prediction -> learn
# Data 394: Original Label -> learn, Prediction -> learn
# Data 395: Original Label -> tree, Prediction -> tree
# Data 396: Original Label -> follow, Prediction -> follow
# Data 397: Original Label -> follow, Prediction -> follow
# Data 398: Original Label -> tree, Prediction -> tree
# Data 399: Original Label -> visual, Prediction -> visual
# Data 400: Original Label -> tree, Prediction -> tree
# Data 401: Original Label -> learn, Prediction -> learn
# Data 402: Original Label -> visual, Prediction -> learn
# Data 403: Original Label -> learn, Prediction -> visual
# Data 404: Original Label -> learn, Prediction -> learn
# Data 405: Original Label -> learn, Prediction -> learn
# Data 406: Original Label -> tree, Prediction -> tree
# Data 407: Original Label -> learn, Prediction -> learn
# Data 408: Original Label -> follow, Prediction -> follow
# Data 409: Original Label -> tree, Prediction -> tree
# Data 410: Original Label -> tree, Prediction -> tree
# Data 411: Original Label -> visual, Prediction -> visual
# Data 412: Original Label -> learn, Prediction -> learn
# Data 413: Original Label -> tree, Prediction -> tree
# Data 414: Original Label -> tree, Prediction -> tree
# Data 415: Original Label -> visual, Prediction -> visual
# Data 416: Original Label -> learn, Prediction -> learn
# Data 417: Original Label -> tree, Prediction -> tree
# Data 418: Original Label -> learn, Prediction -> learn
# Data 419: Original Label -> tree, Prediction -> learn
# Data 420: Original Label -> follow, Prediction -> follow
# Data 421: Original Label -> learn, Prediction -> learn
# Data 422: Original Label -> learn, Prediction -> tree
# Data 423: Original Label -> tree, Prediction -> tree
# Data 424: Original Label -> follow, Prediction -> follow
# Data 425: Original Label -> follow, Prediction -> follow
# Data 426: Original Label -> learn, Prediction -> tree
# Data 427: Original Label -> tree, Prediction -> tree
# Data 428: Original Label -> follow, Prediction -> follow
# Data 429: Original Label -> learn, Prediction -> learn
# Data 430: Original Label -> tree, Prediction -> tree
# Data 431: Original Label -> visual, Prediction -> visual
# Data 432: Original Label -> visual, Prediction -> visual
# Data 433: Original Label -> tree, Prediction -> tree
# Data 434: Original Label -> follow, Prediction -> follow
# Data 435: Original Label -> follow, Prediction -> follow
# Data 436: Original Label -> learn, Prediction -> learn
# Data 437: Original Label -> follow, Prediction -> follow
# Data 438: Original Label -> learn, Prediction -> learn
# Data 439: Original Label -> follow, Prediction -> follow
# Data 440: Original Label -> visual, Prediction -> visual
# Data 441: Original Label -> visual, Prediction -> visual
# Data 442: Original Label -> learn, Prediction -> learn
# Data 443: Original Label -> tree, Prediction -> tree
# Data 444: Original Label -> tree, Prediction -> tree
# Data 445: Original Label -> follow, Prediction -> follow
# Data 446: Original Label -> learn, Prediction -> learn
# Data 447: Original Label -> learn, Prediction -> learn
# Data 448: Original Label -> learn, Prediction -> learn
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Data 449: Original Label -> tree, Prediction -> tree
# Data 450: Original Label -> visual, Prediction -> visual
# Data 451: Original Label -> learn, Prediction -> learn
# Data 452: Original Label -> tree, Prediction -> tree
# Data 453: Original Label -> tree, Prediction -> tree
# Data 454: Original Label -> visual, Prediction -> visual
# Data 455: Original Label -> follow, Prediction -> follow
# Data 456: Original Label -> visual, Prediction -> visual
# Data 457: Original Label -> tree, Prediction -> tree
# Data 458: Original Label -> follow, Prediction -> follow
# Data 459: Original Label -> follow, Prediction -> follow
# Data 460: Original Label -> visual, Prediction -> visual
# Data 461: Original Label -> follow, Prediction -> follow
# Data 462: Original Label -> learn, Prediction -> learn
# Data 463: Original Label -> tree, Prediction -> tree
# Data 464: Original Label -> follow, Prediction -> follow
# Data 465: Original Label -> learn, Prediction -> learn
# Data 466: Original Label -> follow, Prediction -> follow
# Data 467: Original Label -> follow, Prediction -> follow
# Data 468: Original Label -> visual, Prediction -> visual
# Data 469: Original Label -> tree, Prediction -> follow
# Data 470: Original Label -> visual, Prediction -> visual
# Data 471: Original Label -> visual, Prediction -> visual
# Data 472: Original Label -> visual, Prediction -> visual
# Data 473: Original Label -> tree, Prediction -> tree
# Data 474: Original Label -> visual, Prediction -> visual
# Data 475: Original Label -> learn, Prediction -> learn
# Data 476: Original Label -> tree, Prediction -> tree
# Data 477: Original Label -> tree, Prediction -> tree
# Data 478: Original Label -> learn, Prediction -> learn
# Data 479: Original Label -> follow, Prediction -> follow
# Data 480: Original Label -> follow, Prediction -> follow
# Data 481: Original Label -> tree, Prediction -> tree
# Data 482: Original Label -> tree, Prediction -> tree
# Data 483: Original Label -> follow, Prediction -> follow
# Data 484: Original Label -> follow, Prediction -> follow
# Data 485: Original Label -> tree, Prediction -> tree
# Data 486: Original Label -> learn, Prediction -> learn
# Data 487: Original Label -> visual, Prediction -> visual
# Data 488: Original Label -> follow, Prediction -> follow
# Data 489: Original Label -> tree, Prediction -> tree
# Data 490: Original Label -> follow, Prediction -> follow
# Data 491: Original Label -> tree, Prediction -> tree
# Data 492: Original Label -> tree, Prediction -> tree
# Data 493: Original Label -> learn, Prediction -> learn
# Data 494: Original Label -> tree, Prediction -> tree
# Data 495: Original Label -> tree, Prediction -> tree
# Data 496: Original Label -> visual, Prediction -> visual
# Data 497: Original Label -> tree, Prediction -> learn
# Data 498: Original Label -> learn, Prediction -> learn
# Data 499: Original Label -> learn, Prediction -> follow
# Data 500: Original Label -> visual, Prediction -> visual
# Data 501: Original Label -> learn, Prediction -> learn
# Data 502: Original Label -> visual, Prediction -> visual
# Data 503: Original Label -> visual, Prediction -> visual
# Data 504: Original Label -> visual, Prediction -> visual
# Data 505: Original Label -> visual, Prediction -> visual
# Data 506: Original Label -> learn, Prediction -> learn
# Data 507: Original Label -> tree, Prediction -> tree
# Data 508: Original Label -> learn, Prediction -> learn
# Data 509: Original Label -> visual, Prediction -> visual
# Data 510: Original Label -> tree, Prediction -> follow
# Data 511: Original Label -> tree, Prediction -> tree
# Data 512: Original Label -> follow, Prediction -> follow
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Data 513: Original Label -> visual, Prediction -> visual
# Data 514: Original Label -> learn, Prediction -> learn
# Data 515: Original Label -> tree, Prediction -> tree
# Data 516: Original Label -> tree, Prediction -> tree
# Data 517: Original Label -> learn, Prediction -> learn
# Data 518: Original Label -> follow, Prediction -> follow
# Data 519: Original Label -> learn, Prediction -> learn
# Data 520: Original Label -> follow, Prediction -> follow
# Data 521: Original Label -> tree, Prediction -> tree
# Data 522: Original Label -> follow, Prediction -> follow
# Data 523: Original Label -> learn, Prediction -> learn
# Data 524: Original Label -> tree, Prediction -> tree
# Data 525: Original Label -> learn, Prediction -> learn
# Data 526: Original Label -> visual, Prediction -> visual
# Data 527: Original Label -> learn, Prediction -> learn
# Data 528: Original Label -> follow, Prediction -> follow
# Data 529: Original Label -> learn, Prediction -> follow
# Data 530: Original Label -> tree, Prediction -> tree
# Data 531: Original Label -> learn, Prediction -> learn
# Data 532: Original Label -> learn, Prediction -> learn
# Data 533: Original Label -> learn, Prediction -> learn
# Data 534: Original Label -> tree, Prediction -> tree
# Data 535: Original Label -> tree, Prediction -> tree
# Data 536: Original Label -> visual, Prediction -> visual
# Data 537: Original Label -> visual, Prediction -> visual
# Data 538: Original Label -> follow, Prediction -> follow
# Data 539: Original Label -> follow, Prediction -> learn
# Data 540: Original Label -> visual, Prediction -> visual
# Data 541: Original Label -> learn, Prediction -> learn
# Data 542: Original Label -> visual, Prediction -> visual
# Data 543: Original Label -> learn, Prediction -> learn
# Data 544: Original Label -> tree, Prediction -> tree
# Data 545: Original Label -> tree, Prediction -> tree
# Data 546: Original Label -> visual, Prediction -> learn
# Data 547: Original Label -> visual, Prediction -> visual
# Data 548: Original Label -> visual, Prediction -> visual
# Data 549: Original Label -> tree, Prediction -> tree
# Data 550: Original Label -> visual, Prediction -> visual
# Data 551: Original Label -> learn, Prediction -> learn
# Data 552: Original Label -> learn, Prediction -> learn
# Data 553: Original Label -> learn, Prediction -> learn
# Data 554: Original Label -> follow, Prediction -> follow
# Data 555: Original Label -> visual, Prediction -> visual
# Data 556: Original Label -> follow, Prediction -> follow
# Data 557: Original Label -> tree, Prediction -> tree
# Data 558: Original Label -> visual, Prediction -> visual
# Data 559: Original Label -> learn, Prediction -> learn
# Data 560: Original Label -> learn, Prediction -> learn
# Data 561: Original Label -> learn, Prediction -> learn
# Data 562: Original Label -> learn, Prediction -> follow
# Data 563: Original Label -> follow, Prediction -> learn
# Data 564: Original Label -> follow, Prediction -> follow
# Data 565: Original Label -> learn, Prediction -> learn
# Data 566: Original Label -> visual, Prediction -> visual
# Data 567: Original Label -> learn, Prediction -> learn
# Data 568: Original Label -> learn, Prediction -> learn
# Data 569: Original Label -> visual, Prediction -> visual
# Data 570: Original Label -> follow, Prediction -> follow
# Data 571: Original Label -> follow, Prediction -> follow
# Data 572: Original Label -> learn, Prediction -> learn
# Data 573: Original Label -> visual, Prediction -> visual
# Data 574: Original Label -> tree, Prediction -> visual
# Data 575: Original Label -> tree, Prediction -> tree
# Data 576: Original Label -> learn, Prediction -> learn
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Data 577: Original Label -> follow, Prediction -> follow
# Data 578: Original Label -> visual, Prediction -> visual
# Data 579: Original Label -> tree, Prediction -> tree
# Data 580: Original Label -> tree, Prediction -> tree
# Data 581: Original Label -> follow, Prediction -> follow
# Data 582: Original Label -> visual, Prediction -> follow
# Data 583: Original Label -> learn, Prediction -> learn
# Data 584: Original Label -> follow, Prediction -> follow
# Data 585: Original Label -> tree, Prediction -> tree
# Data 586: Original Label -> tree, Prediction -> visual
# Data 587: Original Label -> learn, Prediction -> learn
# Data 588: Original Label -> learn, Prediction -> learn
# Data 589: Original Label -> tree, Prediction -> tree
# Data 590: Original Label -> learn, Prediction -> learn
# Data 591: Original Label -> follow, Prediction -> follow
# Data 592: Original Label -> tree, Prediction -> tree
# Data 593: Original Label -> visual, Prediction -> visual
# Data 594: Original Label -> visual, Prediction -> learn
# Data 595: Original Label -> tree, Prediction -> tree
# Data 596: Original Label -> learn, Prediction -> learn
# Data 597: Original Label -> visual, Prediction -> follow
# Data 598: Original Label -> learn, Prediction -> learn
# Data 599: Original Label -> follow, Prediction -> follow
# Data 600: Original Label -> learn, Prediction -> learn
# Data 601: Original Label -> tree, Prediction -> tree
# Data 602: Original Label -> learn, Prediction -> learn
# Data 603: Original Label -> tree, Prediction -> tree
# Data 604: Original Label -> learn, Prediction -> learn
# Data 605: Original Label -> visual, Prediction -> visual
# Data 606: Original Label -> learn, Prediction -> learn
# Data 607: Original Label -> learn, Prediction -> learn
# Data 608: Original Label -> tree, Prediction -> tree
# Data 609: Original Label -> follow, Prediction -> follow
# Data 610: Original Label -> tree, Prediction -> tree
# Data 611: Original Label -> follow, Prediction -> follow
# Data 612: Original Label -> visual, Prediction -> visual
# Data 613: Original Label -> visual, Prediction -> tree
# Data 614: Original Label -> visual, Prediction -> visual
# Data 615: Original Label -> tree, Prediction -> tree
# Data 616: Original Label -> learn, Prediction -> learn
# Data 617: Original Label -> learn, Prediction -> learn
# Data 618: Original Label -> visual, Prediction -> visual
# Data 619: Original Label -> follow, Prediction -> follow
# Data 620: Original Label -> visual, Prediction -> visual
# Data 621: Original Label -> follow, Prediction -> follow
# Data 622: Original Label -> visual, Prediction -> visual
# Data 623: Original Label -> tree, Prediction -> tree
# Data 624: Original Label -> learn, Prediction -> learn
# Data 625: Original Label -> learn, Prediction -> visual
# Data 626: Original Label -> visual, Prediction -> visual
# Data 627: Original Label -> tree, Prediction -> tree
# Data 628: Original Label -> follow, Prediction -> follow
# Data 629: Original Label -> follow, Prediction -> follow
# Data 630: Original Label -> follow, Prediction -> follow
# Data 631: Original Label -> tree, Prediction -> visual
# Data 632: Original Label -> follow, Prediction -> follow
# Data 633: Original Label -> follow, Prediction -> follow
# Data 634: Original Label -> visual, Prediction -> visual
# Data 635: Original Label -> visual, Prediction -> visual
# Data 636: Original Label -> tree, Prediction -> tree
# Data 637: Original Label -> follow, Prediction -> follow
# Data 638: Original Label -> learn, Prediction -> learn
# Data 639: Original Label -> tree, Prediction -> tree
# Data 640: Original Label -> visual, Prediction -> visual
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Data 641: Original Label -> follow, Prediction -> follow
# Data 642: Original Label -> tree, Prediction -> tree
# Data 643: Original Label -> learn, Prediction -> learn
# Data 644: Original Label -> visual, Prediction -> visual
# Data 645: Original Label -> follow, Prediction -> follow
# Data 646: Original Label -> visual, Prediction -> visual
# Data 647: Original Label -> tree, Prediction -> tree
# Data 648: Original Label -> follow, Prediction -> follow
# Data 649: Original Label -> tree, Prediction -> tree
# Data 650: Original Label -> tree, Prediction -> tree
# Data 651: Original Label -> visual, Prediction -> visual
# Data 652: Original Label -> tree, Prediction -> tree
# Data 653: Original Label -> tree, Prediction -> tree
# Data 654: Original Label -> learn, Prediction -> learn
# Data 655: Original Label -> follow, Prediction -> follow
# Data 656: Original Label -> visual, Prediction -> visual
# Data 657: Original Label -> visual, Prediction -> visual
# Data 658: Original Label -> tree, Prediction -> tree
# Data 659: Original Label -> learn, Prediction -> learn
# Data 660: Original Label -> visual, Prediction -> tree
# Data 661: Original Label -> visual, Prediction -> visual
# Data 662: Original Label -> visual, Prediction -> visual
# Data 663: Original Label -> visual, Prediction -> visual
# Data 664: Original Label -> follow, Prediction -> follow
# Data 665: Original Label -> visual, Prediction -> visual
# Data 666: Original Label -> follow, Prediction -> follow
# Data 667: Original Label -> follow, Prediction -> follow
# Data 668: Original Label -> follow, Prediction -> follow
# Data 669: Original Label -> follow, Prediction -> follow
# Data 670: Original Label -> follow, Prediction -> follow
# Data 671: Original Label -> learn, Prediction -> learn
# Data 672: Original Label -> tree, Prediction -> tree
# Data 673: Original Label -> follow, Prediction -> tree
# Data 674: Original Label -> visual, Prediction -> visual
# Data 675: Original Label -> follow, Prediction -> follow
# Data 676: Original Label -> tree, Prediction -> tree
# Data 677: Original Label -> visual, Prediction -> visual
# Data 678: Original Label -> follow, Prediction -> follow
# Data 679: Original Label -> visual, Prediction -> visual
# Data 680: Original Label -> visual, Prediction -> learn
# Data 681: Original Label -> tree, Prediction -> tree
# Data 682: Original Label -> follow, Prediction -> follow
# Data 683: Original Label -> tree, Prediction -> tree
# Data 684: Original Label -> follow, Prediction -> follow
# Data 685: Original Label -> visual, Prediction -> visual
# Data 686: Original Label -> visual, Prediction -> visual
# Data 687: Original Label -> tree, Prediction -> tree
# Data 688: Original Label -> tree, Prediction -> tree
# Data 689: Original Label -> follow, Prediction -> follow
# Data 690: Original Label -> learn, Prediction -> learn
# Data 691: Original Label -> learn, Prediction -> learn
# Data 692: Original Label -> tree, Prediction -> tree
# Data 693: Original Label -> learn, Prediction -> learn
# Data 694: Original Label -> tree, Prediction -> tree
# Data 695: Original Label -> tree, Prediction -> tree
# Data 696: Original Label -> learn, Prediction -> learn
# Data 697: Original Label -> visual, Prediction -> visual
# Data 698: Original Label -> tree, Prediction -> tree
# Data 699: Original Label -> follow, Prediction -> follow
# Data 700: Original Label -> follow, Prediction -> visual
# Data 701: Original Label -> tree, Prediction -> tree
# Data 702: Original Label -> visual, Prediction -> follow
# Data 703: Original Label -> learn, Prediction -> learn
# Data 704: Original Label -> visual, Prediction -> visual
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Data 705: Original Label -> tree, Prediction -> tree
# Data 706: Original Label -> tree, Prediction -> tree
# Data 707: Original Label -> tree, Prediction -> tree
# Data 708: Original Label -> follow, Prediction -> follow
# Data 709: Original Label -> learn, Prediction -> learn
# Data 710: Original Label -> learn, Prediction -> visual
# Data 711: Original Label -> learn, Prediction -> learn
# Data 712: Original Label -> learn, Prediction -> learn
# Data 713: Original Label -> visual, Prediction -> visual
# Data 714: Original Label -> visual, Prediction -> visual
# Data 715: Original Label -> follow, Prediction -> follow
# Data 716: Original Label -> follow, Prediction -> follow
# Data 717: Original Label -> learn, Prediction -> learn
# Data 718: Original Label -> learn, Prediction -> learn
# Data 719: Original Label -> visual, Prediction -> visual
# Data 720: Original Label -> learn, Prediction -> learn
# Data 721: Original Label -> tree, Prediction -> tree
# Data 722: Original Label -> tree, Prediction -> tree
# Data 723: Original Label -> learn, Prediction -> learn
# Data 724: Original Label -> follow, Prediction -> follow
# Data 725: Original Label -> visual, Prediction -> visual
# Data 726: Original Label -> tree, Prediction -> tree
# Data 727: Original Label -> learn, Prediction -> learn
# Data 728: Original Label -> visual, Prediction -> visual
# Data 729: Original Label -> visual, Prediction -> visual
# Data 730: Original Label -> learn, Prediction -> learn
# Data 731: Original Label -> tree, Prediction -> tree
# Data 732: Original Label -> learn, Prediction -> learn
# Data 733: Original Label -> learn, Prediction -> visual
# Data 734: Original Label -> follow, Prediction -> follow
# Data 735: Original Label -> tree, Prediction -> tree
# Data 736: Original Label -> learn, Prediction -> learn
# Data 737: Original Label -> visual, Prediction -> visual
# Data 738: Original Label -> learn, Prediction -> follow
# Data 739: Original Label -> learn, Prediction -> learn
# Data 740: Original Label -> visual, Prediction -> visual
# Data 741: Original Label -> visual, Prediction -> visual
# Data 742: Original Label -> visual, Prediction -> visual
# Data 743: Original Label -> tree, Prediction -> tree
# Data 744: Original Label -> learn, Prediction -> learn
# Data 745: Original Label -> tree, Prediction -> tree
# Data 746: Original Label -> learn, Prediction -> learn
# Data 747: Original Label -> follow, Prediction -> follow
# Data 748: Original Label -> tree, Prediction -> tree
# Data 749: Original Label -> visual, Prediction -> visual
# Data 750: Original Label -> tree, Prediction -> tree
# Data 751: Original Label -> visual, Prediction -> visual
# Data 752: Original Label -> tree, Prediction -> tree
# Data 753: Original Label -> follow, Prediction -> follow
# Data 754: Original Label -> follow, Prediction -> follow
# Data 755: Original Label -> follow, Prediction -> follow
# Data 756: Original Label -> visual, Prediction -> visual
# Data 757: Original Label -> tree, Prediction -> tree
# Data 758: Original Label -> tree, Prediction -> tree
# Data 759: Original Label -> visual, Prediction -> visual
# Data 760: Original Label -> visual, Prediction -> visual
# Data 761: Original Label -> visual, Prediction -> visual
# Data 762: Original Label -> learn, Prediction -> learn
# Data 763: Original Label -> visual, Prediction -> visual
# Data 764: Original Label -> learn, Prediction -> learn
# Data 765: Original Label -> tree, Prediction -> tree
# Data 766: Original Label -> visual, Prediction -> visual
# Data 767: Original Label -> learn, Prediction -> learn
# Data 768: Original Label -> learn, Prediction -> learn
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Data 769: Original Label -> learn, Prediction -> learn
# Data 770: Original Label -> learn, Prediction -> learn
# Data 771: Original Label -> tree, Prediction -> tree
# Data 772: Original Label -> follow, Prediction -> follow
# Data 773: Original Label -> learn, Prediction -> learn
# Data 774: Original Label -> learn, Prediction -> learn
# Data 775: Original Label -> visual, Prediction -> visual
# Data 776: Original Label -> visual, Prediction -> visual
# Data 777: Original Label -> follow, Prediction -> follow
# Data 778: Original Label -> tree, Prediction -> tree
# Data 779: Original Label -> tree, Prediction -> tree
# Data 780: Original Label -> visual, Prediction -> visual
# Data 781: Original Label -> learn, Prediction -> learn
# Data 782: Original Label -> learn, Prediction -> learn
# Data 783: Original Label -> visual, Prediction -> visual
# Data 784: Original Label -> learn, Prediction -> learn
# Data 785: Original Label -> visual, Prediction -> visual
# Data 786: Original Label -> tree, Prediction -> tree
# Data 787: Original Label -> follow, Prediction -> follow
# Data 788: Original Label -> learn, Prediction -> learn
# Data 789: Original Label -> follow, Prediction -> follow
# Data 790: Original Label -> follow, Prediction -> follow
# Data 791: Original Label -> follow, Prediction -> follow
# Data 792: Original Label -> learn, Prediction -> learn
# Data 793: Original Label -> tree, Prediction -> tree
# Data 794: Original Label -> tree, Prediction -> tree
# Data 795: Original Label -> follow, Prediction -> follow
# Data 796: Original Label -> visual, Prediction -> visual
# Data 797: Original Label -> tree, Prediction -> tree
# Data 798: Original Label -> tree, Prediction -> tree
# Data 799: Original Label -> visual, Prediction -> visual
# Data 800: Original Label -> follow, Prediction -> follow
# Data 801: Original Label -> learn, Prediction -> learn
# Data 802: Original Label -> tree, Prediction -> tree
# Data 803: Original Label -> visual, Prediction -> visual
# Data 804: Original Label -> visual, Prediction -> visual
# Data 805: Original Label -> follow, Prediction -> follow
# Data 806: Original Label -> visual, Prediction -> visual
# Data 807: Original Label -> learn, Prediction -> learn
# Data 808: Original Label -> tree, Prediction -> visual
# Data 809: Original Label -> follow, Prediction -> follow
# Data 810: Original Label -> visual, Prediction -> visual
# Data 811: Original Label -> tree, Prediction -> tree
# Data 812: Original Label -> tree, Prediction -> tree
# Data 813: Original Label -> visual, Prediction -> visual
# Data 814: Original Label -> visual, Prediction -> visual
# Data 815: Original Label -> follow, Prediction -> follow
# Data 816: Original Label -> tree, Prediction -> tree
# Data 817: Original Label -> follow, Prediction -> follow
# Data 818: Original Label -> follow, Prediction -> follow
# Data 819: Original Label -> visual, Prediction -> visual
# Data 820: Original Label -> visual, Prediction -> visual
# Data 821: Original Label -> tree, Prediction -> tree
# Data 822: Original Label -> follow, Prediction -> follow
# Data 823: Original Label -> tree, Prediction -> tree
# Data 824: Original Label -> visual, Prediction -> learn
# Data 825: Original Label -> tree, Prediction -> tree
# Data 826: Original Label -> follow, Prediction -> follow
# Data 827: Original Label -> visual, Prediction -> visual
# Data 828: Original Label -> follow, Prediction -> follow
# Data 829: Original Label -> learn, Prediction -> learn
# Data 830: Original Label -> learn, Prediction -> learn
# Data 831: Original Label -> learn, Prediction -> learn
# Data 832: Original Label -> visual, Prediction -> visual
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Data 833: Original Label -> learn, Prediction -> learn
# Data 834: Original Label -> visual, Prediction -> visual
# Data 835: Original Label -> follow, Prediction -> follow
# Data 836: Original Label -> tree, Prediction -> tree
# Data 837: Original Label -> visual, Prediction -> visual
# Data 838: Original Label -> follow, Prediction -> learn
# Data 839: Original Label -> learn, Prediction -> learn
# Data 840: Original Label -> learn, Prediction -> learn
# Data 841: Original Label -> follow, Prediction -> follow
# Data 842: Original Label -> visual, Prediction -> visual
# Data 843: Original Label -> visual, Prediction -> visual
# Data 844: Original Label -> visual, Prediction -> visual
# Data 845: Original Label -> follow, Prediction -> follow
# Data 846: Original Label -> follow, Prediction -> follow
# Data 847: Original Label -> follow, Prediction -> follow
# Data 848: Original Label -> learn, Prediction -> learn
# Data 849: Original Label -> visual, Prediction -> visual
# Data 850: Original Label -> tree, Prediction -> tree
# Data 851: Original Label -> visual, Prediction -> visual
# Data 852: Original Label -> visual, Prediction -> visual
# Data 853: Original Label -> visual, Prediction -> visual
# Data 854: Original Label -> learn, Prediction -> learn
# Data 855: Original Label -> learn, Prediction -> learn
# Data 856: Original Label -> visual, Prediction -> visual
# Data 857: Original Label -> learn, Prediction -> learn
# Data 858: Original Label -> visual, Prediction -> visual
# Data 859: Original Label -> follow, Prediction -> follow
# Data 860: Original Label -> follow, Prediction -> follow
# Data 861: Original Label -> tree, Prediction -> tree
# Data 862: Original Label -> tree, Prediction -> tree
# Data 863: Original Label -> tree, Prediction -> tree
# Data 864: Original Label -> learn, Prediction -> tree
# Data 865: Original Label -> learn, Prediction -> learn
# Data 866: Original Label -> visual, Prediction -> visual
# Data 867: Original Label -> follow, Prediction -> follow
# Data 868: Original Label -> tree, Prediction -> tree
# Data 869: Original Label -> tree, Prediction -> tree
# Data 870: Original Label -> learn, Prediction -> learn
# Data 871: Original Label -> tree, Prediction -> tree
# Data 872: Original Label -> follow, Prediction -> follow
# Data 873: Original Label -> learn, Prediction -> learn
# Data 874: Original Label -> visual, Prediction -> visual
# Data 875: Original Label -> learn, Prediction -> learn
# Data 876: Original Label -> visual, Prediction -> tree
# Data 877: Original Label -> follow, Prediction -> follow
# Data 878: Original Label -> tree, Prediction -> tree
# Data 879: Original Label -> follow, Prediction -> follow
# Data 880: Original Label -> learn, Prediction -> learn
# Data 881: Original Label -> follow, Prediction -> follow
# Data 882: Original Label -> tree, Prediction -> tree
# Data 883: Original Label -> visual, Prediction -> visual
# Data 884: Original Label -> visual, Prediction -> learn
# Data 885: Original Label -> follow, Prediction -> follow
# Data 886: Original Label -> visual, Prediction -> visual
# Data 887: Original Label -> tree, Prediction -> tree
# Data 888: Original Label -> visual, Prediction -> visual
# Data 889: Original Label -> follow, Prediction -> follow
# Data 890: Original Label -> visual, Prediction -> visual
# Data 891: Original Label -> visual, Prediction -> visual
# Data 892: Original Label -> learn, Prediction -> learn
# Data 893: Original Label -> learn, Prediction -> visual
# Data 894: Original Label -> tree, Prediction -> tree
# Data 895: Original Label -> visual, Prediction -> visual
# Data 896: Original Label -> visual, Prediction -> visual
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Data 897: Original Label -> learn, Prediction -> learn
# Data 898: Original Label -> visual, Prediction -> visual
# Data 899: Original Label -> visual, Prediction -> visual
# Data 900: Original Label -> tree, Prediction -> tree
# Data 901: Original Label -> follow, Prediction -> follow
# Data 902: Original Label -> follow, Prediction -> follow
# Data 903: Original Label -> follow, Prediction -> follow
# Data 904: Original Label -> visual, Prediction -> visual
# Data 905: Original Label -> learn, Prediction -> learn
# Data 906: Original Label -> learn, Prediction -> learn
# Data 907: Original Label -> follow, Prediction -> follow
# Data 908: Original Label -> visual, Prediction -> visual
# Data 909: Original Label -> visual, Prediction -> visual
# Data 910: Original Label -> visual, Prediction -> visual
# Data 911: Original Label -> follow, Prediction -> follow
# Data 912: Original Label -> follow, Prediction -> follow
# Data 913: Original Label -> visual, Prediction -> visual
# Data 914: Original Label -> visual, Prediction -> visual
# Data 915: Original Label -> visual, Prediction -> visual
# Data 916: Original Label -> follow, Prediction -> follow
# Data 917: Original Label -> learn, Prediction -> learn
# Data 918: Original Label -> visual, Prediction -> visual
# Data 919: Original Label -> tree, Prediction -> tree
# Data 920: Original Label -> visual, Prediction -> visual
# Data 921: Original Label -> learn, Prediction -> learn
# Data 922: Original Label -> tree, Prediction -> tree
# Data 923: Original Label -> learn, Prediction -> learn
# Data 924: Original Label -> visual, Prediction -> visual
# Data 925: Original Label -> learn, Prediction -> learn
# Data 926: Original Label -> visual, Prediction -> visual
# Data 927: Original Label -> follow, Prediction -> follow
# Data 928: Original Label -> visual, Prediction -> visual
# Data 929: Original Label -> tree, Prediction -> tree
# Data 930: Original Label -> visual, Prediction -> visual
# Data 931: Original Label -> visual, Prediction -> visual
# Data 932: Original Label -> tree, Prediction -> tree
# Data 933: Original Label -> visual, Prediction -> visual
# Data 934: Original Label -> tree, Prediction -> tree
# Data 935: Original Label -> learn, Prediction -> learn
# Data 936: Original Label -> visual, Prediction -> visual
# Data 937: Original Label -> visual, Prediction -> visual
# Data 938: Original Label -> learn, Prediction -> learn
# Data 939: Original Label -> follow, Prediction -> follow
# Data 940: Original Label -> learn, Prediction -> learn
# Data 941: Original Label -> learn, Prediction -> learn
# Data 942: Original Label -> tree, Prediction -> tree
# Data 943: Original Label -> follow, Prediction -> follow
# Data 944: Original Label -> learn, Prediction -> learn
# Data 945: Original Label -> learn, Prediction -> learn
# Data 946: Original Label -> follow, Prediction -> follow
# Data 947: Original Label -> learn, Prediction -> learn
# Data 948: Original Label -> visual, Prediction -> visual
# Data 949: Original Label -> tree, Prediction -> tree
# Data 950: Original Label -> visual, Prediction -> visual
# Data 951: Original Label -> follow, Prediction -> follow
# Data 952: Original Label -> tree, Prediction -> tree
# Data 953: Original Label -> follow, Prediction -> follow
# Data 954: Original Label -> visual, Prediction -> visual
# Data 955: Original Label -> visual, Prediction -> visual
# Data 956: Original Label -> learn, Prediction -> learn
# Data 957: Original Label -> visual, Prediction -> tree
# Data 958: Original Label -> follow, Prediction -> follow
# Data 959: Original Label -> visual, Prediction -> visual
# Data 960: Original Label -> tree, Prediction -> tree
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Data 961: Original Label -> learn, Prediction -> learn
# Data 962: Original Label -> follow, Prediction -> follow
# Data 963: Original Label -> learn, Prediction -> learn
# Data 964: Original Label -> learn, Prediction -> learn
# Data 965: Original Label -> learn, Prediction -> learn
# Data 966: Original Label -> tree, Prediction -> tree
# Data 967: Original Label -> visual, Prediction -> tree
# Data 968: Original Label -> learn, Prediction -> learn
# Data 969: Original Label -> visual, Prediction -> learn
# Data 970: Original Label -> visual, Prediction -> visual
# Data 971: Original Label -> learn, Prediction -> learn
# Data 972: Original Label -> follow, Prediction -> follow
# Data 973: Original Label -> learn, Prediction -> learn
# Data 974: Original Label -> learn, Prediction -> learn
# Data 975: Original Label -> learn, Prediction -> visual
# Data 976: Original Label -> learn, Prediction -> learn
# Data 977: Original Label -> learn, Prediction -> learn
# Data 978: Original Label -> follow, Prediction -> follow
# Data 979: Original Label -> visual, Prediction -> visual
# Data 980: Original Label -> tree, Prediction -> tree
# Data 981: Original Label -> visual, Prediction -> visual
# Data 982: Original Label -> visual, Prediction -> visual
# Data 983: Original Label -> tree, Prediction -> tree
# Data 984: Original Label -> follow, Prediction -> follow
# Data 985: Original Label -> visual, Prediction -> visual
# Data 986: Original Label -> tree, Prediction -> tree
# Data 987: Original Label -> visual, Prediction -> visual
# Data 988: Original Label -> tree, Prediction -> tree
# Data 989: Original Label -> learn, Prediction -> learn
# Data 990: Original Label -> learn, Prediction -> learn
# Data 991: Original Label -> learn, Prediction -> learn
